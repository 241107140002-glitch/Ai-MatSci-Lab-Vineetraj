# %%
### Session 10

# %%
import pandas as pd
from ydata_profiling import ProfileReport
from sklearn.impute import SimpleImputer, KNNImputer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import pandas as pd
# ----> 2 from ydata_profiling import ProfileReport
#       3 from sklearn.impute import SimpleImputer, KNNImputer
#
# File D:\anaconda\Lib\site-packages\ydata_profiling\__init__.py:11
#       8 import importlib.util  # isort:skip # noqa
#       9 from warnings import warn
# ---> 11 from ydata_profiling.compare_reports import compare  # isort:skip # noqa
#      12 from ydata_profiling.controller import pandas_decorator  # isort:skip # noqa
#      13 from ydata_profiling.profile_report import ProfileReport  # isort:skip # noqa
#
# File D:\anaconda\Lib\site-packages\ydata_profiling\compare_reports.py:12
#      10 from ydata_profiling.model import BaseDescription
#      11 from ydata_profiling.model.alerts import Alert
# ---> 12 from ydata_profiling.profile_report import ProfileReport
#      15 def _should_wrap(v1: Any, v2: Any) -> bool:
#      16     if isinstance(v1, (list, dict)):
#
# File D:\anaconda\Lib\site-packages\ydata_profiling\profile_report.py:11
#       9 with warnings.catch_warnings():
#      10     warnings.simplefilter("ignore")
# ---> 11     import pkg_resources
#      13 if not is_pyspark_installed():
#      14     from typing import TypeVar
#
# ModuleNotFoundError: No module named 'pkg_resources'

# %%
# !pip install -U setuptools
# Out:
# Requirement already satisfied: setuptools in d:\anaconda\lib\site-packages (83.0.0)
# Collecting setuptools
#   Downloading setuptools-84.0.0-py3-none-any.whl.metadata (6.6 kB)
# Downloading setuptools-84.0.0-py3-none-any.whl (818 kB)
#    ---------------------------------------- 0.0/818.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/818.2 kB ? eta -:--:--
#    ------------ --------------------------- 262.1/818.2 kB ? eta -:--:--
#    ------------------------ ------------- 524.3/818.2 kB 989.2 kB/s eta 0:00:01
#    ---------------------------------------- 818.2/818.2 kB 1.0 MB/s eta 0:00:00
# Installing collected packages: setuptools
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 83.0.0
#     Uninstalling setuptools-83.0.0:
#       Successfully uninstalled setuptools-83.0.0
# Successfully installed setuptools-84.0.0
# WARNING: Ignoring invalid distribution ~etworkx (D:\anaconda\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ympy (D:\anaconda\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~etworkx (D:\anaconda\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ympy (D:\anaconda\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~etworkx (D:\anaconda\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ympy (D:\anaconda\Lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda 24.11.3 requires ruamel-yaml<0.19,>=0.11.14, but you have ruamel-yaml 0.19.1 which is incompatible.

# %%
# !conda install -y
"resume1.yaml<0.19"
# Out:
# CondaValueError: too few arguments, must supply command line package specs or --file
# 'resume1.yaml<0.19'

# %%
import ruamel.yaml
print(ruamel.yaml.__version__)
# Out:
# 0.19.1

# %%
# !pip install ydata-profiling
# Out:
# Requirement already satisfied: ydata-profiling in d:\anaconda\lib\site-packages (4.18.4)
# Requirement already satisfied: scipy<1.17,>=1.8 in d:\anaconda\lib\site-packages (from ydata-profiling) (1.16.3)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.5 in d:\anaconda\lib\site-packages (from ydata-profiling) (2.3.3)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in d:\anaconda\lib\site-packages (from ydata-profiling) (3.10.0)
# Requirement already satisfied: pydantic<3,>=2 in d:\anaconda\lib\site-packages (from ydata-profiling) (2.13.4)
# Requirement already satisfied: PyYAML<6.1,>=6.0.3 in d:\anaconda\lib\site-packages (from ydata-profiling) (6.0.3)
# Requirement already satisfied: jinja2<3.2,>=3.1.6 in d:\anaconda\lib\site-packages (from ydata-profiling) (3.1.6)
# Requirement already satisfied: visions<0.8.2,>=0.7.5 in d:\anaconda\lib\site-packages (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (0.8.1)
# Requirement already satisfied: numpy<2.4,>=1.22 in d:\anaconda\lib\site-packages (from ydata-profiling) (2.2.5)
# Requirement already satisfied: minify-html>=0.15.0 in d:\anaconda\lib\site-packages (from ydata-profiling) (0.18.1)
# Requirement already satisfied: filetype>=1.0.0 in d:\anaconda\lib\site-packages (from ydata-profiling) (1.2.0)
# Requirement already satisfied: phik<0.13,>=0.12.5 in d:\anaconda\lib\site-packages (from ydata-profiling) (0.12.5)
# Requirement already satisfied: requests<3,>=2.32.0 in d:\anaconda\lib\site-packages (from ydata-profiling) (2.34.2)
# Requirement already satisfied: tqdm<5,>=4.66.3 in d:\anaconda\lib\site-packages (from ydata-profiling) (4.69.1)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in d:\anaconda\lib\site-packages (from ydata-profiling) (0.13.2)
# Requirement already satisfied: multimethod<2,>=1.4 in d:\anaconda\lib\site-packages (from ydata-profiling) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in d:\anaconda\lib\site-packages (from ydata-profiling) (0.14.6)
# Requirement already satisfied: typeguard<5,>=4 in d:\anaconda\lib\site-packages (from ydata-profiling) (4.6.0)
# Requirement already satisfied: imagehash==4.3.2 in d:\anaconda\lib\site-packages (from ydata-profiling) (4.3.2)
# Requirement already satisfied: wordcloud>=1.9.4 in d:\anaconda\lib\site-packages (from ydata-profiling) (1.9.6)
# Requirement already satisfied: dacite<2,>=1.9 in d:\anaconda\lib\site-packages (from ydata-profiling) (1.9.2)
# Requirement already satisfied: numba<0.63,>=0.60 in d:\anaconda\lib\site-packages (from ydata-profiling) (0.62.1)
# Requirement already satisfied: PyWavelets in d:\anaconda\lib\site-packages (from imagehash==4.3.2->ydata-profiling) (1.9.0)
# Requirement already satisfied: pillow in d:\anaconda\lib\site-packages (from imagehash==4.3.2->ydata-profiling) (12.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\anaconda\lib\site-packages (from jinja2<3.2,>=3.1.6->ydata-profiling) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in d:\anaconda\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\anaconda\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (26.3)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\anaconda\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anaconda\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in d:\anaconda\lib\site-packages (from numba<0.63,>=0.60->ydata-profiling) (0.45.1)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda\lib\site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2026.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in d:\anaconda\lib\site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2026.3)
# Requirement already satisfied: joblib>=0.14.1 in d:\anaconda\lib\site-packages (from phik<0.13,>=0.12.5->ydata-profiling) (1.5.3)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\anaconda\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (0.6.0)
# Requirement already satisfied: pydantic-core==2.46.4 in d:\anaconda\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (2.46.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in d:\anaconda\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (4.16.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\anaconda\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\anaconda\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.7)
# Requirement already satisfied: urllib3<3,>=1.26 in d:\anaconda\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in d:\anaconda\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (2026.7.22)
# Requirement already satisfied: patsy>=0.5.6 in d:\anaconda\lib\site-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (1.0.2)
# Requirement already satisfied: colorama in d:\anaconda\lib\site-packages (from tqdm<5,>=4.66.3->ydata-profiling) (0.4.6)
# Requirement already satisfied: attrs>=19.3.0 in d:\anaconda\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (23.1.0)
# Requirement already satisfied: networkx>=2.4 in d:\anaconda\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (3.6.1)
# Requirement already satisfied: puremagic in d:\anaconda\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (2.2.0)
# Requirement already satisfied: six>=1.5 in d:\anaconda\lib\site-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata-profiling) (1.17.0)
# WARNING: Ignoring invalid distribution ~etworkx (D:\anaconda\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ympy (D:\anaconda\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~etworkx (D:\anaconda\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ympy (D:\anaconda\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~etworkx (D:\anaconda\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ympy (D:\anaconda\Lib\site-packages)

# %%
from ydata_profiling import ProfileReport
print("ydata-profiling installed successfully")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from ydata_profiling import ProfileReport
#       2 print("ydata-profiling installed successfully")
#
# File D:\anaconda\Lib\site-packages\ydata_profiling\__init__.py:11
#       8 import importlib.util  # isort:skip # noqa
#       9 from warnings import warn
# ---> 11 from ydata_profiling.compare_reports import compare  # isort:skip # noqa
#      12 from ydata_profiling.controller import pandas_decorator  # isort:skip # noqa
#      13 from ydata_profiling.profile_report import ProfileReport  # isort:skip # noqa
#
# File D:\anaconda\Lib\site-packages\ydata_profiling\compare_reports.py:12
#      10 from ydata_profiling.model import BaseDescription
#      11 from ydata_profiling.model.alerts import Alert
# ---> 12 from ydata_profiling.profile_report import ProfileReport
#      15 def _should_wrap(v1: Any, v2: Any) -> bool:
#      16     if isinstance(v1, (list, dict)):
#
# File D:\anaconda\Lib\site-packages\ydata_profiling\profile_report.py:11
#       9 with warnings.catch_warnings():
#      10     warnings.simplefilter("ignore")
# ---> 11     import pkg_resources
#      13 if not is_pyspark_installed():
#      14     from typing import TypeVar
#
# ModuleNotFoundError: No module named 'pkg_resources'

# %%
# !pip install "setuptools==80.9.0"
# Out:
# Collecting setuptools==80.9.0
#   Downloading setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# Downloading setuptools-80.9.0-py3-none-any.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    -------- ------------------------------- 0.3/1.2 MB ? eta -:--:--
#    ----------------- ---------------------- 0.5/1.2 MB 1.0 MB/s eta 0:00:01
#    -------------------------- ------------- 0.8/1.2 MB 1.1 MB/s eta 0:00:01
#    -------------------------- ------------- 0.8/1.2 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.0/1.2 MB 915.5 kB/s eta 0:00:01
#    ---------------------------------------- 1.2/1.2 MB 871.4 kB/s eta 0:00:00
# Installing collected packages: setuptools
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 84.0.0
#     Uninstalling setuptools-84.0.0:
#       Successfully uninstalled setuptools-84.0.0
# Successfully installed setuptools-80.9.0
# WARNING: Ignoring invalid distribution ~etworkx (D:\anaconda\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ympy (D:\anaconda\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~etworkx (D:\anaconda\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ympy (D:\anaconda\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~etworkx (D:\anaconda\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ympy (D:\anaconda\Lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda 24.11.3 requires ruamel-yaml<0.19,>=0.11.14, but you have ruamel-yaml 0.19.1 which is incompatible.

# %%
import pkg_resources
print("pkg_resources OK")
# Out:
# pkg_resources OK
# C:\Users\rk307\AppData\Local\Temp\ipykernel_10408\1495694699.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
from ydata_profiling import ProfileReport
print("ydata-profiling installed successfully")
# Out:
# D:\anaconda\Lib\site-packages\networkx\utils\backends.py:102: RuntimeWarning: networkx backend defined more than once: nx_loopback
#   backends = _get_backends("networkx.backends")
# ydata-profiling installed successfully
# C:\Users\rk307\AppData\Local\Temp\ipykernel_10408\3721660681.py:1: DeprecationWarning:
#     `import ydata_profiling` is deprecated and will not receive more updates.
#     Please install fg-data-profiling via `pip install fg-data-profiling` and use `import data_profiling` instead.
#
#   from ydata_profiling import ProfileReport

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\rk307

# %%
import pandas as pd
import os

print(os.getcwd())
print(os.listdir())
# Out:
# C:\Users\rk307
# ['-1.14-windows.xml', '.anaconda', '.android', '.bubblewrap', '.conda', '.condarc', '.config', '.continuum', '.copilot', '.emulator_console_auth_token', '.gitconfig', '.gradle', '.ipynb_checkpoints', '.ipython', '.jupyter', '.mamba', '.matplotlib', '.VirtualBox', '.vscode', '.vscode-shared', 'AndroidStudioProjects', 'AppData', 'Application Data', 'candid', 'candid.zip', 'Cookies', 'Documents', 'Downloads', 'Dropbox', 'Favorites', 'Local Settings', 'module 1', 'module SO7', 'monster-hunter-online', 'Music', 'My Documents', 'NetHood', 'NTUSER.DAT', 'ntuser.dat.LOG1', 'ntuser.dat.LOG2', 'NTUSER.DAT{2ad838bc-efea-11ee-a54d-000d3a94eaa1}.TM.blf', 'NTUSER.DAT{2ad838bc-efea-11ee-a54d-000d3a94eaa1}.TMContainer00000000000000000001.regtrans-ms', 'NTUSER.DAT{2ad838bc-efea-11ee-a54d-000d3a94eaa1}.TMContainer00000000000000000002.regtrans-ms', 'ntuser.ini', 'OneDrive', 'perovskites_data.csv', 'Pictures', 'PrintHood', 'Recent', 'Saved Games', 'Searches', 'SendTo', 'Start Menu', 'Templates', 'Untitled.ipynb', 'Untitled1.ipynb', 'Untitled10.ipynb', 'Untitled11.ipynb', 'Untitled12.ipynb', 'Untitled13.ipynb', 'Untitled14.ipynb', 'Untitled15.ipynb', 'Untitled16.ipynb', 'Untitled17.ipynb', 'Untitled18.ipynb', 'Untitled19.ipynb', 'Untitled2.ipynb', 'Untitled3.ipynb', 'Untitled4.ipynb', 'Untitled5.ipynb', 'Untitled6.ipynb', 'Untitled7.ipynb', 'Untitled8.ipynb', 'Untitled9.ipynb', 'Videos', 'VirtualBox VMs', 'work3.ipynb', 'WPS Cloud Files']

# %%
import os

print("CSV files:")
print([file for file in os.listdir() if file.endswith(".csv")])
# Out:
# CSV files:
# ['perovskites_data.csv']

# %%
import pandas as pd

df = pd.read_csv("perovskites_data.csv")

print("CSV loaded successfully!")
print(df.head())
# Out:
# CSV loaded successfully!
#   Material_ID Formula  Bandgap  Formation_Energy     Volume
# 0  mp-1183115  AcAlO3   4.1024         -3.690019  57.451413
# 1  mp-1183052   AcBO3   0.8071         -2.475390  51.548126
# 2   mp-866101  AcCrO3   2.0031         -3.138972  61.362845
# 3   mp-864606  AcCuO3   0.0000         -2.422892  59.929387
# 4   mp-861502  AcFeO3   1.0084         -2.771539  61.797311

# %%
print("Shape:", df.shape)
print("\nColumns:")
print(df.columns)

print("\nInformation:")
df.info()
# Out:
# Shape: (4719, 5)
#
# Columns:
# Index(['Material_ID', 'Formula', 'Bandgap', 'Formation_Energy', 'Volume'], dtype='object')
#
# Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4719 entries, 0 to 4718
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Material_ID       4719 non-null   object
#  1   Formula           4719 non-null   object
#  2   Bandgap           4719 non-null   float64
#  3   Formation_Energy  4719 non-null   float64
#  4   Volume            4719 non-null   float64
# dtypes: float64(3), object(2)
# memory usage: 184.5+ KB

# %%
# 2. Generate the Automated Profiling Report
profile = ProfileReport(df, title="Perovskites Data Profiling Report")
profile.to_file("perovskites_report.html")
print("✅ Profiling report generated and saved as HTML.")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|██████████| 5/5 [00:00<00:00, 19.86it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# ✅ Profiling report generated and saved as HTML.

# %%
# 3. Handle Missing Values: Mean Imputation
mean_imputer = SimpleImputer(strategy='mean')
df_mean_imputed = df.copy()
# Assuming 'Bandgap' has missing values
df_mean_imputed[['Bandgap']] = mean_imputer.fit_transform(df[['Bandgap']])

# %%
# 4. Handle Missing Values: KNN Imputation
knn_imputer = KNNImputer(n_neighbors=5)
df_knn_imputed = df.copy()
df_knn_imputed[['Bandgap']] = knn_imputer.fit_transform(df[['Bandgap']])

print("✅ Missing data successfully imputed using Mean and KNN strategies.")
# Out:
# ✅ Missing data successfully imputed using Mean and KNN strategies.
